# %% [markdown]
# <h1 style = "color:#400403; text-align: center; font-weight: bold"> Universidad Castro Carazo </h1>
# <h3 style = "color:#822d34; text-align: center">  Proyecto Analisis de Datos </h3>
# <h5 style = "color:#d15a67; text-align: center"> Venta de bienes raices </h5>
# <h5 style = "color:#d15a67; text-align: center"> Estudiantes: Karina Salazar Gonzalez y Ana Belen Salazar Gonzalez</h5>
# <center> <img src = "acuerdo.png"> </center>
# </br> <!-- Esta linea crea un ENTER -->
# <p style = "text-align: justify; font-family: Tahoma" > Este proyecto pretende ayudar a la empresa PK2 a esclarecer algunas interrogantes y formar una estrategia de venta de propiedades en alguna ciudad. </p>

# %% [markdown]
# <table>
#   <tr>
#     <td><img src = "informacion (1).png"></td>
#     <td>Repositorio del set de datos</td>
#     <td><a href ="https://www.kaggle.com/datasets/utkarshx27/real-estate-sales-2001-2020-gl">Enlace al Sitio Web</a> </td>
#   </tr>
#   <tr>
#     <td><img src = "circulo-de-color.png"></td>
#     <td>Paleta de Colores</td>
#     <td><a href ="https://paletadecolores.com.mx/paleta/d15a67/a9434e/822d34/5a161a/320000/">Enlace al Sitio Web</a></td>
#   </tr>
# </table>

# %% [markdown]
# <h3 Style="color:#5a161a">1. Carga y estandarizacion de los set de datos</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sn

# %%
dfventas=pd.read_csv("DataSet_ventas.csv",sep =";",low_memory=False)
dfventas.head(5)
# Out:
#   Serial Number List Year Date Recorded     Town                Address  \
# 0       2020348      2020     9/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#   Assessed Value Sale Amount Sales Ratio Property Type Residential Type  ...  \
# 0         150500      325000       0.463    Commercial              NaN  ...
# 1         253000      430000      0.5883   Residential    Single Family  ...
# 2         130400      179900      0.7248   Residential            Condo  ...
# 3         619290      890000      0.6958   Residential    Single Family  ...
# 4         862330     1447500      0.5957   Residential    Single Family  ...
#
#   Unnamed: 129 Unnamed: 130 Unnamed: 131 Unnamed: 132 Unnamed: 133  \
# ...

# %%
print(dfventas.columns)
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type',
#        ...
#        'Unnamed: 129', 'Unnamed: 130', 'Unnamed: 131', 'Unnamed: 132',
#        'Unnamed: 133', 'Unnamed: 134', 'Unnamed: 135', 'Unnamed: 136',
#        'Unnamed: 137', 'Unnamed: 138'],
#       dtype='object', length=139)

# %%
# Filtrar las columnas que contienen "Unnamed" en su nombre
columns_to_drop = [col for col in dfventas.columns if 'Unnamed' in col or ',' in col]

# Eliminar las columnas filtradas
dfventas.drop(columns=columns_to_drop, inplace=True)

# Reiniciar el índice del dataframe
dfventas.reset_index(drop=True, inplace=True)

# Mostrar las primeras filas del dataframe modificado
print(dfventas.head())
# Out:
#   Serial Number List Year Date Recorded     Town                Address  \
# 0       2020348      2020     9/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#   Assessed Value Sale Amount Sales Ratio Property Type Residential Type  \
# 0         150500      325000       0.463    Commercial              NaN
# 1         253000      430000      0.5883   Residential    Single Family
# 2         130400      179900      0.7248   Residential            Condo
# 3         619290      890000      0.6958   Residential    Single Family
# 4         862330     1447500      0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# ...

# %%
# Imprimir las columnas del DataFrame
print("Columnas antes de eliminar:", dfventas.columns)

# Lista de columnas innecesarias
columns_to_drop = ['Non Use Code', 'Assessor Remarks', 'OPM remarks', 'Location']  # Reemplaza con los nombres de las columnas que deseas eliminar

# Eliminar las columnas innecesarias
dfventas.drop(columns=columns_to_drop, inplace=True)

# Reiniciar el índice del DataFrame
dfventas.reset_index(drop=True, inplace=True)

# Mostrar las primeras filas del DataFrame modificado
print("Columnas después de eliminar:", dfventas.columns)
print(dfventas.head())
# Out:
# Columnas antes de eliminar: Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Assessor Remarks', 'OPM remarks',
#        'Location'],
#       dtype='object')
# Columnas después de eliminar: Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type'],
#       dtype='object')
#   Serial Number List Year Date Recorded     Town                Address  \
# 0       2020348      2020     9/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
# ...

# %%
dfventas.head(15)
# Out:
#    Serial Number List Year Date Recorded        Town                Address  \
# 0        2020348      2020     9/13/2021     Ansonia        230 WAKELEE AVE
# 1          20002      2020     10/2/2020     Ashford        390 TURNPIKE RD
# 2         200212      2020      3/9/2021        Avon       5 CHESTNUT DRIVE
# 3         200243      2020     4/13/2021        Avon  111 NORTHINGTON DRIVE
# 4         200377      2020      7/2/2021        Avon     70 FAR HILLS DRIVE
# 5         200109      2020     12/9/2020        Avon     57 FAR HILLS DRIVE
# 6        2020180      2020      3/1/2021      Berlin    1539 FARMINGTON AVE
# 7        2020313      2020      7/1/2021      Berlin      216 WATCH HILL RD
# 8         200097      2020      6/4/2021     Bethany            23 AMITY RD
# 9          20139      2020    12/16/2020      Bethel      16 DEEPWOOD DRIVE
# 10        200086      2020     8/10/2021   Bethlehem         39 WOODLAND RD
# ...

# %%
dfventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190020 entries, 0 to 190019
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     190008 non-null  object
#  1   List Year         189946 non-null  object
#  2   Date Recorded     189940 non-null  object
#  3   Town              189943 non-null  object
#  4   Address           189934 non-null  object
#  5   Assessed Value    189936 non-null  object
#  6   Sale Amount       189935 non-null  object
#  7   Sales Ratio       189934 non-null  object
#  8   Property Type     56583 non-null   object
#  9   Residential Type  51647 non-null   object
# dtypes: object(10)
# memory usage: 14.5+ MB

# %%
dfventas.rename({'Serial Number':'serial_number', 'List Year':'list_year', 'Date Recorded':'data_recorded', 'Town':'town', 'Address':'address', 
               'Assessed Value':'assesed_value', 'Sale Amount':'sale_amount', 'Sales Ratio':'sales_ratio', 'Property Type':'property_type', 
               'Residential Type':'residential_type', 'Non Use Code':'non_use_code', 'Assessor Remarks':'assessor_remarks', 'OPM remarks':'opm_remarks',
                'Location':'location'},axis=1, inplace=True) #axis=0 es para cambiar solo indices. axis=1 para cambiar columnas 
dfventas.columns
# Out:
# Index(['serial_number', 'list_year', 'data_recorded', 'town', 'address',
#        'assesed_value', 'sale_amount', 'sales_ratio', 'property_type',
#        'residential_type'],
#       dtype='object')

# %%
dfventas.head()
# Out:
#   serial_number list_year data_recorded     town                address  \
# 0       2020348      2020     9/13/2021  Ansonia        230 WAKELEE AVE
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#   assesed_value sale_amount sales_ratio property_type residential_type
# 0        150500      325000       0.463    Commercial              NaN
# 1        253000      430000      0.5883   Residential    Single Family
# 2        130400      179900      0.7248   Residential            Condo
# 3        619290      890000      0.6958   Residential    Single Family
# 4        862330     1447500      0.5957   Residential    Single Family

# %%
dfventas.tail()
# Out:
#        serial_number list_year data_recorded           town         address  \
# 190015         20763      2002     6/17/2003     West Haven    130 JONES ST
# 190016         21066      2002     7/22/2003  West Hartford    15 PORTER DR
# 190017         30531      2003     4/15/2004  East Hartford   43 TIFFANY RD
# 190018         30624      2003      3/3/2004        Bristol   81 ANDREWS ST
# 190019         30434      2003      2/6/2004      Greenwich  57 PROSPECT ST
#
#        assesed_value sale_amount  sales_ratio property_type residential_type
# 190015         70700      179000  0.394972067           NaN              NaN
# 190016        240880      515000  0.467728155           NaN              NaN
# 190017         80330      130000  0.617923077           NaN              NaN
# 190018         69230      130000  0.532538462           NaN              NaN
# 190019        183470      375000  0.489253333           NaN              NaN

# %%
dfventas['list_year'].unique()
# Out:
# array(['2020', '2001', '2002', nan, '166400', '2003', '144550',
#        '07 - Change in Property', 'Single Family',
#        ' 2 PARCELS SOLD TOGETHER', ' WF/RIVER', 'Residential', '63920',
#        '2004', '2005', '2006', '2007', '2008', '2009', 'Condo', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019'], dtype=object)

# %%
dfventas['data_recorded'].unique()
# Out:
# array(['9/13/2021', '10/2/2020', '3/9/2021', ..., '9/26/2004',
#        '7/24/2004', '2/29/2004'], dtype=object)

# %%
dfventas['town'].unique()
# Out:
# array(['Ansonia', 'Ashford', 'Avon', 'Berlin', 'Bethany', 'Bethel',
#        'Bethlehem', 'Bloomfield', 'Branford', 'Bristol', 'Brookfield',
#        'Canaan', 'Canton', 'Cheshire', 'Chester', 'Colchester',
#        'Columbia', 'Cornwall', 'Coventry', 'Cromwell', 'Danbury', 'Derby',
#        'Eastford', 'East Haddam', 'East Haven', 'Farmington', 'Chaplin',
#        'Clinton', 'East Lyme', 'Easton', 'Enfield', 'Essex', 'Durham',
#        'Franklin', 'Glastonbury', 'Hamden', 'Granby', 'Greenwich',
#        'Colebrook', 'East Windsor', 'Griswold', 'Bolton', 'Groton',
#        'Guilford', 'Hartford', 'Harwinton', 'Milford', 'Killingly',
#        'Killingworth', 'Lebanon', 'Lisbon', 'Litchfield', 'Lyme',
#        'Manchester', 'Putnam', 'Norwalk', 'Stafford', 'Mansfield',
#        'Sherman', 'Meriden', 'Stratford', 'Roxbury', 'Oxford', 'Old Lyme',
#        'Norwich', 'Sharon', 'Monroe', 'Tolland', 'Torrington',
#        'Naugatuck', 'Ridgefield', 'New London', 'New Britain', 'Orange',
# ...

# %%
dfventas['address'].unique()
# Out:
# array(['230 WAKELEE AVE', '390 TURNPIKE RD', '5 CHESTNUT DRIVE', ...,
#        '15 PORTER DR', '43 TIFFANY RD', '81 ANDREWS ST'], dtype=object)

# %%
dfventas['assesed_value'].unique()
# Out:
# array(['150500', '253000', '130400', ..., '730240', '240890', '240880'],
#       dtype=object)

# %%
dfventas['sale_amount'].unique()
# Out:
# array(['325000', '430000', '179900', ..., '269995', '298999', '824860'],
#       dtype=object)

# %%
dfventas['sales_ratio'].unique()
# Out:
# array(['0.463', '0.5883', '0.7248', ..., '0.617923077', '0.532538462',
#        '0.489253333'], dtype=object)

# %%
dfventas['property_type'].unique()
# Out:
# array(['Commercial', 'Residential', 'Vacant Land', nan, 'Apartments',
#        'Industrial', 'Public Utility', 'Condo', 'Two Family',
#        ';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;',
#        'Three Family', 'Single Family'], dtype=object)

# %%
dfventas['residential_type'].unique()
# Out:
# array([nan, 'Single Family', 'Condo', 'Two Family', 'Three Family',
#        'Four Family', 'POINT (-72.49422 41.78123)'], dtype=object)

# %%
dfTemp=dfventas.isnull()#isnull identifica valores faltantes, devuelve resultado true o false, true valor faltante #dftemp es un data frame temporal
dfTemp.head(2)
# Out:
#    serial_number  list_year  data_recorded   town  address  assesed_value  \
# 0          False      False          False  False    False          False
# 1          False      False          False  False    False          False
#
#    sale_amount  sales_ratio  property_type  residential_type
# 0        False        False          False              True
# 1        False        False          False             False

# %%
for columns in dfTemp.columns.values.tolist(): #convierte la columna en una lista 
    print(dfTemp[columns].value_counts())
    print('')
# Out:
# serial_number
# False    190008
# True         12
# Name: count, dtype: int64
#
# list_year
# False    189946
# True         74
# Name: count, dtype: int64
#
# data_recorded
# False    189940
# True         80
# Name: count, dtype: int64
#
# town
# False    189943
# True         77
# Name: count, dtype: int64
#
# address
# False    189934
# True         86
# Name: count, dtype: int64
#
# assesed_value
# False    189936
# True         84
# Name: count, dtype: int64
#
# sale_amount
# False    189935
# True         85
# Name: count, dtype: int64
#
# sales_ratio
# False    189934
# True         86
# Name: count, dtype: int64
#
# property_type
# True     133437
# False     56583
# Name: count, dtype: int64
#
# residential_type
# True     138373
# False     51647
# Name: count, dtype: int64

# %%
# Eliminar valores faltantes
dfventas.dropna(inplace=True)

# Eliminar valores irrelevantes o erróneos
dfventas = dfventas[dfventas['property_type'] != ';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;']

# Estandarizar formatos (por ejemplo, convertir a mayúsculas)
dfventas['property_type'] = dfventas['property_type'].str.upper()

# Eliminar duplicados
dfventas.drop_duplicates(inplace=True)

# Mostrar el DataFrame temporal limpio
print("DataFrame temporal limpio:")
print(dfTemp.head())
# Out:
# DataFrame temporal limpio:
#    serial_number  list_year  data_recorded   town  address  assesed_value  \
# 0          False      False          False  False    False          False
# 1          False      False          False  False    False          False
# 2          False      False          False  False    False          False
# 3          False      False          False  False    False          False
# 4          False      False          False  False    False          False
#
#    sale_amount  sales_ratio  property_type  residential_type
# 0        False        False          False              True
# 1        False        False          False             False
# 2        False        False          False             False
# 3        False        False          False             False
# 4        False        False          False             False

# %%
# Eliminar valores faltantes
dfventas.dropna(inplace=True)

# Eliminar valores irrelevantes o erróneos
dfventas = dfventas[dfventas['residential_type'] != ';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;']

# Estandarizar formatos (por ejemplo, convertir a mayúsculas)
dfventas['residential_type'] = dfventas['residential_type'].str.upper()

# Eliminar duplicados
dfventas.drop_duplicates(inplace=True)

# Mostrar el DataFrame temporal limpio
print("DataFrame temporal limpio:")
print(dfventas.head())
# Out:
# DataFrame temporal limpio:
#   serial_number list_year data_recorded     town                address  \
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
# 5        200109      2020     12/9/2020     Avon     57 FAR HILLS DRIVE
#
#   assesed_value sale_amount sales_ratio property_type residential_type
# 1        253000      430000      0.5883   RESIDENTIAL    SINGLE FAMILY
# 2        130400      179900      0.7248   RESIDENTIAL            CONDO
# 3        619290      890000      0.6958   RESIDENTIAL    SINGLE FAMILY
# 4        862330     1447500      0.5957   RESIDENTIAL    SINGLE FAMILY
# 5        847520     1250000       0.678   RESIDENTIAL    SINGLE FAMILY

# %%
dfventas['property_type'].unique()
# Out:
# array(['RESIDENTIAL', 'CONDO', 'TWO FAMILY', 'THREE FAMILY',
#        'SINGLE FAMILY'], dtype=object)

# %%
dfventas['residential_type'].unique()
# Out:
# array(['SINGLE FAMILY', 'CONDO', 'TWO FAMILY', 'THREE FAMILY',
#        'FOUR FAMILY'], dtype=object)

# %%
dfventas.head(5)
# Out:
#   serial_number list_year data_recorded     town                address  \
# 1         20002      2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2        200212      2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3        200243      2020     4/13/2021     Avon  111 NORTHINGTON DRIVE
# 4        200377      2020      7/2/2021     Avon     70 FAR HILLS DRIVE
# 5        200109      2020     12/9/2020     Avon     57 FAR HILLS DRIVE
#
#   assesed_value sale_amount sales_ratio property_type residential_type
# 1        253000      430000      0.5883   RESIDENTIAL    SINGLE FAMILY
# 2        130400      179900      0.7248   RESIDENTIAL            CONDO
# 3        619290      890000      0.6958   RESIDENTIAL    SINGLE FAMILY
# 4        862330     1447500      0.5957   RESIDENTIAL    SINGLE FAMILY
# 5        847520     1250000       0.678   RESIDENTIAL    SINGLE FAMILY

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #1</h4>
# <h5>Cual es el ingreso anual de las propiedades vendidas?</h5>

# %%
# Asegúrate de que sale_amount es numérico
dfventas['sale_amount'] = pd.to_numeric(dfventas['sale_amount'], errors='coerce')

# Asegúrate de que data_recorded es tipo datetime
dfventas['data_recorded'] = pd.to_datetime(dfventas['data_recorded'], errors='coerce')

# Extraer el año
dfventas['Year'] = dfventas['data_recorded'].dt.year

# Agrupar por año y sumar correctamente
ingreso_anual = dfventas.groupby('Year')['sale_amount'].sum().reset_index(name='ingreso_total')

# Mostrar resultados
print(ingreso_anual)
# Out:
#     Year  ingreso_total
# 0   2006   1.691000e+06
# 1   2007   8.311400e+06
# 2   2008   7.817915e+06
# 3   2009   2.110675e+06
# 4   2010   3.926040e+06
# 5   2011   5.624070e+06
# 6   2012   2.900450e+06
# 7   2013   4.194995e+06
# 8   2014   3.117900e+06
# 9   2015   7.079205e+06
# 10  2016   4.502760e+06
# 11  2017   5.590000e+06
# 12  2018   1.172468e+07
# 13  2019   8.985000e+06
# 14  2020   6.111678e+09
# 15  2021   1.903496e+10

# %%
import matplotlib.pyplot as plt

# Crear figura y eje
fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

# Graficar barras horizontales
ax.barh(ingreso_anual['Year'], ingreso_anual['ingreso_total'], color='skyblue')

# Configuración del gráfico
ax.set_xlabel("Ingreso Total ($)", fontsize=12, fontweight="bold")
ax.set_ylabel("Año", fontsize=12, fontweight="bold")
ax.set_title("Gráfico 1: Ingreso Anual por Venta de Propiedades", fontsize=14, fontweight="bold")

# Ajustar eje X para que las barras no queden pegadas al borde
ax.set_xlim(0, ingreso_anual['ingreso_total'].max() * 1.1)

# Agregar etiquetas de valor al final de cada barra
for i, valor in enumerate(ingreso_anual['ingreso_total']):
    ax.text(valor + (ingreso_anual['ingreso_total'].max() * 0.01), ingreso_anual['Year'][i], 
            f"${valor:,.2f}", va='center', fontsize=9)

# Ajustar márgenes
plt.tight_layout()

# Guardar el gráfico
fig.savefig("Grafico_Ingreso_Anual_Ventas_Horizontal", dpi=300, bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #2</h4>
# <h5>Que tipo de propiedad tiene mayor facilidad de venta?</h5>

# %%
import matplotlib as mpl

mpl.rcParams["axes.spines.bottom"]=True #para quitar las lineas de la caja que encierra el grafico 
mpl.rcParams["axes.spines.top"]=False
mpl.rcParams["axes.spines.left"]=True
mpl.rcParams["axes.spines.right"]=False

# %%
def agrupaYcuenta(df, columna, ordenar):
    return df.groupby(columna).size().reset_index(name='cantidad').sort_values(by='cantidad', ascending=ordenar)

# %%
def agrupaYcuenta(dfParam, nomColumna, orden):
    gf = dfParam.groupby([nomColumna]).count()
    gf = gf.iloc[:, 0:1]  # Selecciona solo la primera columna
    gf.columns = ['cantidad']  # Renombra esa columna sin importar su nombre original
    gf = gf.sort_values("cantidad", ascending=orden)
    return gf

# %%
dfAgrupado=agrupaYcuenta(dfventas, 'property_type', False)
#------------------------------------GRAFICO DE BARRAS--------------------------------------#

fig, ax = plt.subplots(1,1, figsize=(15, 6.9), dpi=100) #se definen las parcelas, tamaño del grafico

etiquetaBarras = dfAgrupado.index.tolist() ## Es el nombre de cada una de las barras en eje X
alturaBarras = dfAgrupado['cantidad'].tolist() # Este es el valor que define el tamano de las graficas
coloresBarras=["#fce7d2","#e0dbbd","#c0ceaa","#fd8086","#eb5874"]

gBarra=ax.bar(etiquetaBarras, alturaBarras, color=coloresBarras)


#-------------------------------------------------------------------------------------------#
#------------------------------------CONF. DEL GRAFICO--------------------------------------#
#-------------------------------------------------------------------------------------------#

titulo = "Venta de Bienes Raíces 2001-2020"
plt.suptitle(titulo,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')
 
subtitulo = "Ventas según tipo de propiedad"
ax.set_title(subtitulo,
            ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')
etiquetax = "Tipo de propiedad"
ax.set_xlabel(etiquetax,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')
 
etiquetay = "Cantidad de propiedades"
ax.set_ylabel(etiquetay,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')
 
ax.xaxis.set_label_coords(x=0, y = - 0.10, transform = ax.transAxes)
ax.yaxis.set_label_coords(x=-0.08, y = 0.40, transform = ax.transAxes)

#---------------------------------------------------------------------------------------------#
#-------------------------------Crear etiqueta para cada barra--------------------------------#
#---------------------------------------------------------------------------------------------#
informacion_barras = [f"{tipo}: {cant}" for tipo, cant in zip(etiquetaBarras, alturaBarras)]

for barra, etiqueta in zip(gBarra, informacion_barras):
    altura = barra.get_height()
    ax.text(barra.get_x() + barra.get_width() / 2, altura, etiqueta, 
            ha='center', va='bottom', fontsize=10, color='black')
ax.set_xticklabels([])  # Oculta las etiquetas de texto
#---------------------------------------------------------------------------------------------#

plt.subplots_adjust(top=0.75)
fig.savefig(f"Grafico_tipos_propiedad_{ciudad_top['town']}.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #3</h4>
# <h5>En cual cuidad o pueblo se dan mayor cantidad de ventas de propiedades? Que elementos particulares tiene esas ciudades o pueblos??</h5>

# %%
df_ciudad_top.loc[:, 'assesed_value'] = pd.to_numeric(df_ciudad_top['assesed_value'], errors='coerce')

# %%
num_nans = df_ciudad_top['assesed_value'].isna().sum()
print(f"Número de valores no convertibles a numérico (NaN): {num_nans}")
# Out:
# Número de valores no convertibles a numérico (NaN): 0

# %%
# Contar las ventas por ciudad
ventas_por_ciudad = dfventas.groupby('town').size().reset_index(name='cantidad')

# Identificar la ciudad con mayor cantidad de ventas
ciudad_top = ventas_por_ciudad.sort_values('cantidad', ascending=False).iloc[0]
print(f"La ciudad con más ventas es: {ciudad_top['town']} con {ciudad_top['cantidad']} ventas.")

# Filtrar los datos de la ciudad con más ventas
df_ciudad_top = dfventas[dfventas['town'] == ciudad_top['town']].copy()

# Convertir 'assesed_value' a numérico, forzando errores a NaN
df_ciudad_top['assesed_value'] = pd.to_numeric(df_ciudad_top['assesed_value'], errors='coerce')

# Calcular el precio medio, ignorando NaN
precio_medio = df_ciudad_top['assesed_value'].mean()

# Obtener tipos de propiedad y año más común
tipos = df_ciudad_top['property_type'].value_counts()
anio_mas_comun = df_ciudad_top['data_recorded'].mode()[0]

print("Tipos de propiedad en la ciudad con más ventas:")
print(tipos)
print(f"Precio medio de las propiedades: {precio_medio:.2f}")
print(f"Año más común de registro: {anio_mas_comun}")
# Out:
# La ciudad con más ventas es: Stamford con 2472 ventas.
# Tipos de propiedad en la ciudad con más ventas:
# property_type
# RESIDENTIAL    2469
# CONDO             3
# Name: count, dtype: int64
# Precio medio de las propiedades: 358446.44
# Año más común de registro: 1/15/2021

# %%
import matplotlib.pyplot as plt

# Crear figura
fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

# Crear gráfico de barras para los tipos de propiedad
ax.bar(tipos.index, tipos.values, color="#87ceeb", alpha=0.8)

# Configuraciones
ax.set_xlabel("Tipo de Propiedad", fontsize=12, fontweight="bold")
ax.set_ylabel("Cantidad de Propiedades", fontsize=12, fontweight="bold")
ax.set_title(f"Gráfico: Tipos de Propiedad en {ciudad_top['town']}\nPrecio Medio: ${precio_medio:,.2f}", 
             fontsize=14, fontweight="bold")

# Rotar etiquetas si son largas
plt.xticks(rotation=45)

# Añadir etiquetas encima de cada barra
for i, valor in enumerate(tipos.values):
    ax.text(i, valor + 0.5, str(valor), ha='center', va='bottom', fontsize=10)

# Ajustar diseño
plt.tight_layout()

# Guardar el gráfico
fig.savefig(f"Grafico_tipos_propiedad_{ciudad_top['town']}.png", dpi=300, bbox_inches='tight')

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Asegurarnos de que 'data_recorded' sea tipo datetime
df_ciudad_top['data_recorded'] = pd.to_datetime(df_ciudad_top['data_recorded'], errors='coerce')

# Extraer el año solamente
df_ciudad_top['year_recorded'] = df_ciudad_top['data_recorded'].dt.year

# Contar cantidad de propiedades por año
ventas_por_anio = df_ciudad_top['year_recorded'].value_counts().sort_index()

# Crear figura
fig, ax = plt.subplots(figsize=(10, 6), dpi=100)

# Crear gráfico de barras
ax.bar(ventas_por_anio.index, ventas_por_anio.values, color="#f4a460", alpha=0.8)

# Configuraciones
ax.set_xlabel("Año de Registro", fontsize=12, fontweight="bold")
ax.set_ylabel("Cantidad de Propiedades", fontsize=12, fontweight="bold")
ax.set_title(f"Gráfico: Propiedades Registradas por Año en {ciudad_top['town']}", 
             fontsize=14, fontweight="bold")

# Añadir etiquetas encima de las barras
for i, valor in enumerate(ventas_por_anio.values):
    ax.text(ventas_por_anio.index[i], valor + 0.5, str(valor), ha='center', va='bottom', fontsize=10)

# Ajustar diseño
plt.tight_layout()

# Guardar el gráfico
fig.savefig(f"Grafico_propiedades_por_anio_{ciudad_top['town']}.png", dpi=300, bbox_inches='tight')

# Mostrar gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Ordenar ciudades por cantidad de ventas (ya lo tienes)
ventas_por_ciudad_sorted = ventas_por_ciudad.sort_values('cantidad', ascending=False).head(10)

# Crear figura y ejes
fig, ax = plt.subplots(figsize=(12, 6), dpi=100)

# Definir colores personalizados (puedes ajustar o repetir colores si quieres)
colores = ['#a2caa5', '#f4a460', '#87ceeb', '#dda0dd', '#ffb6c1', '#98fb98', '#ffa07a', '#e6e6fa', '#afeeee', '#f08080']

# Crear gráfico de barras
ax.bar(ventas_por_ciudad_sorted['town'], ventas_por_ciudad_sorted['cantidad'], color=colores[:len(ventas_por_ciudad_sorted)])

# Configuración de etiquetas y título
ax.set_xlabel("Ciudad", fontsize=12, fontweight="bold")
ax.set_ylabel("Cantidad de ventas", fontsize=12, fontweight="bold")
ax.set_title("Gráfico 3: Top 10 ciudades con más ventas", fontsize=14, fontweight="bold")

# Rotar etiquetas del eje X
plt.xticks(rotation=45)

# Añadir texto sobre las barras
for i, valor in enumerate(ventas_por_ciudad_sorted['cantidad']):
    ax.text(i, valor + 1, f'{valor}', ha='center', va='bottom', fontsize=10)

# Ajustar diseño
plt.tight_layout()

# Guardar gráfico
fig.savefig("Grafico_3", dpi=300, bbox_inches='tight')

# Mostrar gráfico
plt.show()

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #4</h4>
# <h5>Cual es el costo promedio de las propiedades comerciales y residenciales?</h5>

# %%
# Filtrar datos y calcular promedio
residential_avg = dfventas[dfventas['property_type'] == 'RESIDENTIAL']['assesed_value'].mean()
commercial_avg = dfventas[dfventas['property_type'] == 'COMMERCIAL']['assesed_value'].mean()

# Ajustar valores mínimos para evitar barras invisibles
commercial_avg = commercial_avg if commercial_avg > 0 else 1

# Crear DataFrame con los valores a graficar
data = {'Tipo de Propiedad': ['RESIDENTIAL', 'COMMERCIAL'],
        'Costo Promedio': [residential_avg, commercial_avg]}

# Graficar
fig, ax = plt.subplots(figsize=(8, 5), dpi=100)
ax.bar(data['Tipo de Propiedad'], data['Costo Promedio'], color=['#a2caa5', '#f4a460'])

# Configuración del eje Y para que siempre se vean las barras
ax.set_ylim(0, max(residential_avg, commercial_avg) * 1.1)

# Configuración del gráfico
ax.set_xlabel("Tipo de Propiedad", fontsize=12, fontweight="bold")
ax.set_ylabel("Costo Promedio", fontsize=12, fontweight="bold")
ax.set_title("Gráfico 4: Costo Promedio entre Propiedades Residenciales y Comerciales", fontsize=14, fontweight="bold")

# Añadir texto en las barras
for i, valor in enumerate([residential_avg, commercial_avg]):
    ax.text(i, valor + 1, f'{valor:.2f}', ha='center', va='bottom', fontsize=10)

# Mostrar gráfico
fig.savefig("Grafico_4", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #5</h4>
# <h5>Cual es el tipo de propiedades residenciales que se vende con mayor frecuencia, donde y con que costo promedio?</h5>

# %%
# Filtrar valores nulos antes de contar y calcular el costo promedio
dfventas_filtrado = dfventas.dropna(subset=['residential_type', 'assesed_value'])

# Agrupar por tipo de residencia y calcular la cantidad de ventas y el costo promedio
residential_counts = dfventas_filtrado['residential_type'].value_counts()
residential_avg_cost = dfventas_filtrado.groupby('residential_type')['assesed_value'].mean()

# Crear figura y eje
fig, ax = plt.subplots(figsize=(15,6.9), dpi=100)

# Definir lista de colores específica (ajusta según la cantidad de categorías)
colores = ["#b2cbae","#76877d","#88b8a9","#b2cbae","#dbddb4"]  # Añade más colores si es necesario

# Gráfico de barras con colores personalizados
ax.bar(residential_counts.index, residential_counts.values, color=colores[:len(residential_counts.index)], alpha=0.8)

# Etiquetas y títulos
titulo = "Gráfico 5: Tipo de propiedad residencial más vendida y su costo promedio"
plt.suptitle(titulo,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=20,
             fontweight="bold",
             fontfamily='serif')

subTitulo = "Cantidad de ventas por tipo de residencia y su costo promedio"
ax.set_title(subTitulo,
             ha='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=12,
             fontweight="regular",
             fontfamily="serif")

ax.set_xlabel("Tipo de Residencia",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")

ax.set_ylabel("Cantidad de Ventas",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")

# Añadir etiquetas de costo promedio
for i, v in enumerate(residential_counts.index):
    ax.text(i, residential_counts[v], f"{residential_avg_cost[v]:.2f}", ha='center', fontsize=10, fontweight="bold")

plt.xticks(rotation=45)
plt.subplots_adjust(top=0.75)
fig.savefig("Grafico_residential_type_mas_vendido", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Agrupar por dirección y sumar los valores de venta
ventas_acumuladas = single_family_data.groupby('address')['assesed_value'].sum()

# Verificar que no esté vacío antes de buscar la venta más alta
if not ventas_acumuladas.empty:
    direccion_top = ventas_acumuladas.idxmax()
    venta_total = ventas_acumuladas.max()
    
    print(f"La dirección con la mayor suma total de ventas de 'Single Family' es: {direccion_top}")
    print(f"Suma total de ventas: ${venta_total:,.2f}")
else:
    print("No hay datos suficientes para calcular las ventas acumuladas por dirección.")
# Out:
# No hay datos suficientes para calcular las ventas acumuladas por dirección.

# %% [markdown]
# <h4 style="color:#efae78; font-family: Tahoma">Pregunta de negocio #6</h4>
# <h5>Cual es el margen promedio de ganancia por cada una de las propiedades vendidas?</h5>

# %%
dfventas['sale_amount'] = pd.to_numeric(dfventas['sale_amount'], errors='coerce')


dfventas_filtrado = dfventas.dropna(subset=['sale_amount'])

# %%
dfAgrupado = dfventas_filtrado.groupby('residential_type').agg({
    'sale_amount': 'mean',
}).rename(columns={'sale_amount': 'margen_promedio'})

# %%
import matplotlib.pyplot as plt

# Filtrar valores nulos antes de contar y calcular el margen promedio
dfventas_filtrado = dfventas.dropna(subset=['residential_type', 'sale_amount'])

# Agrupar por tipo de residencia y calcular la cantidad de ventas y el margen promedio
residential_counts = dfventas_filtrado['residential_type'].value_counts()
residential_avg_margin = dfventas_filtrado.groupby('residential_type')['sale_amount'].mean()

# Crear figura y eje
fig, ax = plt.subplots(figsize=(15, 6.9), dpi=100)

# Definir lista de colores específica
colores = ["#b2cbae", "#76877d", "#88b8a9", "#b2cbae", "#dbddb4"]  # Ajusta si tienes más categorías

# Gráfico de barras horizontal
ax.barh(residential_counts.index, residential_counts.values, color=colores[:len(residential_counts.index)], alpha=0.8)

# Etiquetas y títulos
titulo = "Gráfico 6: Tipo de propiedad residencial más vendida y su margen promedio de ganancia"
plt.suptitle(titulo,
             horizontalalignment='left',
             x=0.001,
             y=0.87,
             transform=fig.transFigure,
             fontsize=20,
             fontweight="bold",
             fontfamily='serif')

subTitulo = "Cantidad de ventas por tipo de residencia y su margen promedio de ganancia"
ax.set_title(subTitulo,
             ha='left',
             x=0.001,
             y=0.80,
             transform=fig.transFigure,
             fontsize=12,
             fontweight="regular",
             fontfamily="serif")

ax.set_xlabel("Cantidad de Ventas",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")

ax.set_ylabel("Tipo de Residencia",
              ha='left',
              fontsize=10,
              fontweight="regular",
              fontfamily="serif")

# Añadir etiquetas de margen promedio de ganancia
for i, v in enumerate(residential_counts.index):
    ax.text(residential_counts[v] + max(residential_counts.values)*0.01, i, 
            f"{residential_avg_margin[v]:.2f}", 
            va='center', 
            fontsize=10, 
            fontweight="bold")

plt.subplots_adjust(top=0.75)
fig.savefig("Grafico_residential_type_mas_vendido_margen_horizontal", dpi=300, bbox_inches='tight')
plt.show()
